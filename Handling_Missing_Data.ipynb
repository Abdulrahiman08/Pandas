# %%
import pandas as pd

# %%
df=pd.read_excel("Book.xlsx")

# %%
df
# Out:
#         Location   Population  Percentage       Date                  Source
# 0  United States  335893238.0       0.041 2024-01-01                     NaN
# 1      Indonesia  279118866.0       0.034 2023-07-01      2022 census result
# 2       Pakistan  241499431.0       0.030 2023-03-01   2023 census result[9]
# 3        Nigeria          NaN         NaN 2023-07-01                     NaN
# 4         Brazil  203080756.0       0.025 2022-08-01  2022 census result[11]
# 5     Bangladesh  169828911.0       0.021 2022-06-14  2022 census result[12]

# %%
#fillna
#fills NaN values with given value in entire data frame
df1=df.fillna(0)

# %%
df1
# Out:
#         Location   Population  Percentage       Date                  Source
# 0  United States  335893238.0       0.041 2024-01-01                       0
# 1      Indonesia  279118866.0       0.034 2023-07-01      2022 census result
# 2       Pakistan  241499431.0       0.030 2023-03-01   2023 census result[9]
# 3        Nigeria          0.0       0.000 2023-07-01                       0
# 4         Brazil  203080756.0       0.025 2022-08-01  2022 census result[11]
# 5     Bangladesh  169828911.0       0.021 2022-06-14  2022 census result[12]

# %%
#To fill different values for different cols we need to give it in dic
df2=df.fillna({"Population":0,"Percentage":"0%"})

# %%
df2
# Out:
#         Location   Population Percentage       Date                  Source
# 0  United States  335893238.0      0.041 2024-01-01                     NaN
# 1      Indonesia  279118866.0      0.034 2023-07-01      2022 census result
# 2       Pakistan  241499431.0       0.03 2023-03-01   2023 census result[9]
# 3        Nigeria          0.0         0% 2023-07-01                     NaN
# 4         Brazil  203080756.0      0.025 2022-08-01  2022 census result[11]
# 5     Bangladesh  169828911.0      0.021 2022-06-14  2022 census result[12]

# %%
df
# Out:
#         Location   Population  Percentage       Date                  Source
# 0  United States  335893238.0       0.041 2024-01-01                     NaN
# 1      Indonesia  279118866.0       0.034 2023-07-01      2022 census result
# 2       Pakistan  241499431.0       0.030 2023-03-01   2023 census result[9]
# 3        Nigeria          NaN         NaN 2023-07-01                     NaN
# 4         Brazil  203080756.0       0.025 2022-08-01  2022 census result[11]
# 5     Bangladesh  169828911.0       0.021 2022-06-14  2022 census result[12]

# %%
#Carry forward previvous value to NaN 
df3=df.ffill()

# %%
df3
# Out:
#         Location   Population  Percentage       Date                  Source
# 0  United States  335893238.0       0.041 2024-01-01                     NaN
# 1      Indonesia  279118866.0       0.034 2023-07-01      2022 census result
# 2       Pakistan  241499431.0       0.030 2023-03-01   2023 census result[9]
# 3        Nigeria  241499431.0       0.030 2023-07-01   2023 census result[9]
# 4         Brazil  203080756.0       0.025 2022-08-01  2022 census result[11]
# 5     Bangladesh  169828911.0       0.021 2022-06-14  2022 census result[12]

# %%
#bfill fill the next value
df3=df.bfill()

# %%
df3
# Out:
#         Location   Population  Percentage       Date                  Source
# 0  United States  335893238.0       0.041 2024-01-01      2022 census result
# 1      Indonesia  279118866.0       0.034 2023-07-01      2022 census result
# 2       Pakistan  241499431.0       0.030 2023-03-01   2023 census result[9]
# 3        Nigeria  203080756.0       0.025 2023-07-01  2022 census result[11]
# 4         Brazil  203080756.0       0.025 2022-08-01  2022 census result[11]
# 5     Bangladesh  169828911.0       0.021 2022-06-14  2022 census result[12]

# %%
df2
# Out:
#         Location   Population Percentage       Date                  Source
# 0  United States  335893238.0      0.041 2024-01-01                     NaN
# 1      Indonesia  279118866.0      0.034 2023-07-01      2022 census result
# 2       Pakistan  241499431.0       0.03 2023-03-01   2023 census result[9]
# 3        Nigeria          0.0         0% 2023-07-01                     NaN
# 4         Brazil  203080756.0      0.025 2022-08-01  2022 census result[11]
# 5     Bangladesh  169828911.0      0.021 2022-06-14  2022 census result[12]

# %%
#to drop rows which have NaN
df2.dropna()
# Out:
#      Location   Population Percentage       Date                  Source
# 1   Indonesia  279118866.0      0.034 2023-07-01      2022 census result
# 2    Pakistan  241499431.0       0.03 2023-03-01   2023 census result[9]
# 4      Brazil  203080756.0      0.025 2022-08-01  2022 census result[11]
# 5  Bangladesh  169828911.0      0.021 2022-06-14  2022 census result[12]

# %%
df4=pd.read_excel("Book.xlsx",na_values=["0.021","0.025"])

# %%
df4
# Out:
#         Location   Population  Percentage       Date                  Source
# 0  United States  335893238.0       0.041 2024-01-01                     NaN
# 1      Indonesia  279118866.0       0.034 2023-07-01      2022 census result
# 2       Pakistan  241499431.0       0.030 2023-03-01   2023 census result[9]
# 3        Nigeria          NaN         NaN 2023-07-01                     NaN
# 4         Brazil  203080756.0         NaN 2022-08-01  2022 census result[11]
# 5     Bangladesh  169828911.0         NaN 2022-06-14  2022 census result[12]

# %%
#limit--for ex if there is 3 cells in column is NaN if we want only to carry farward the value to 2 cells in that case limit helps
df4.ffill(limit=1)
# Out:
#         Location   Population  Percentage       Date                  Source
# 0  United States  335893238.0       0.041 2024-01-01                     NaN
# 1      Indonesia  279118866.0       0.034 2023-07-01      2022 census result
# 2       Pakistan  241499431.0       0.030 2023-03-01   2023 census result[9]
# 3        Nigeria  241499431.0       0.030 2023-07-01   2023 census result[9]
# 4         Brazil  203080756.0         NaN 2022-08-01  2022 census result[11]
# 5     Bangladesh  169828911.0         NaN 2022-06-14  2022 census result[12]

# %%
df4
# Out:
#         Location   Population  Percentage       Date                  Source
# 0  United States  335893238.0       0.041 2024-01-01                     NaN
# 1      Indonesia  279118866.0       0.034 2023-07-01      2022 census result
# 2       Pakistan  241499431.0       0.030 2023-03-01   2023 census result[9]
# 3        Nigeria          NaN         NaN 2023-07-01                     NaN
# 4         Brazil  203080756.0         NaN 2022-08-01  2022 census result[11]
# 5     Bangladesh  169828911.0         NaN 2022-06-14  2022 census result[12]

# %%
#interpolate give avg value between above and below values
df4.interpolate(method ='linear', limit_direction ='forward')
# Out:
# C:\Users\rahim\AppData\Local\Temp\ipykernel_4212\1434927903.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df4.interpolate(method ='linear', limit_direction ='forward')
#         Location   Population  Percentage       Date                  Source
# 0  United States  335893238.0       0.041 2024-01-01                     NaN
# 1      Indonesia  279118866.0       0.034 2023-07-01      2022 census result
# 2       Pakistan  241499431.0       0.030 2023-03-01   2023 census result[9]
# 3        Nigeria  222290093.5       0.030 2023-07-01                     NaN
# 4         Brazil  203080756.0       0.030 2022-08-01  2022 census result[11]
# 5     Bangladesh  169828911.0       0.030 2022-06-14  2022 census result[12]

# %%
#replace a data in DF
import numpy as np
df4.replace(169828911.0,np.NaN)
# Out:
#         Location   Population  Percentage       Date                  Source
# 0  United States  335893238.0       0.041 2024-01-01                     NaN
# 1      Indonesia  279118866.0       0.034 2023-07-01      2022 census result
# 2       Pakistan  241499431.0       0.030 2023-03-01   2023 census result[9]
# 3        Nigeria          NaN         NaN 2023-07-01                     NaN
# 4         Brazil  203080756.0         NaN 2022-08-01  2022 census result[11]
# 5     Bangladesh          NaN         NaN 2022-06-14  2022 census result[12]

# %%
#replace 2 values in DF need to give list
df4.replace([169828911.0,279118866.0],np.NaN)
# Out:
#         Location   Population  Percentage       Date                  Source
# 0  United States  335893238.0       0.041 2024-01-01                     NaN
# 1      Indonesia          NaN       0.034 2023-07-01      2022 census result
# 2       Pakistan  241499431.0       0.030 2023-03-01   2023 census result[9]
# 3        Nigeria          NaN         NaN 2023-07-01                     NaN
# 4         Brazil  203080756.0         NaN 2022-08-01  2022 census result[11]
# 5     Bangladesh          NaN         NaN 2022-06-14  2022 census result[12]

# %%
# replace values based on columns
df4.replace({"Population":241499431.0,"Percentage":0.030},np.NaN)
# Out:
#         Location   Population  Percentage       Date                  Source
# 0  United States  335893238.0       0.041 2024-01-01                     NaN
# 1      Indonesia  279118866.0       0.034 2023-07-01      2022 census result
# 2       Pakistan          NaN         NaN 2023-03-01   2023 census result[9]
# 3        Nigeria          NaN         NaN 2023-07-01                     NaN
# 4         Brazil  203080756.0         NaN 2022-08-01  2022 census result[11]
# 5     Bangladesh  169828911.0         NaN 2022-06-14  2022 census result[12]

# %%
# replace a list of values with another list
df4.replace([0.041,0.034],[0.4,0.3])
# Out:
#         Location   Population  Percentage       Date                  Source
# 0  United States  335893238.0        0.40 2024-01-01                     NaN
# 1      Indonesia  279118866.0        0.30 2023-07-01      2022 census result
# 2       Pakistan  241499431.0        0.03 2023-03-01   2023 census result[9]
# 3        Nigeria          NaN         NaN 2023-07-01                     NaN
# 4         Brazil  203080756.0         NaN 2022-08-01  2022 census result[11]
# 5     Bangladesh  169828911.0         NaN 2022-06-14  2022 census result[12]

# %%
df4.groupby("Date").get_group("2023-07-01")
# Out:
#     Location   Population  Percentage       Date              Source
# 1  Indonesia  279118866.0       0.034 2023-07-01  2022 census result
# 3    Nigeria          NaN         NaN 2023-07-01                 NaN

# %%
data1 = {'Name':['Jai', 'Anuj', 'Jai', 'Princi', 
                 'Gaurav', 'Anuj', 'Princi', 'Abhi'], 
        'Age':[27, 24, 22, 32, 
               33, 36, 27, 32], 
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj',
                   'Jaunpur', 'Kanpur', 'Allahabad', 'Aligarh'], 
        'Qualification':['Msc', 'MA', 'MCA', 'Phd',
                         'B.Tech', 'B.com', 'Msc', 'MA']} 
df=pd.DataFrame(data1)

# %%
df
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1    Anuj   24     Kanpur            MA
# 2     Jai   22  Allahabad           MCA
# 3  Princi   32    Kannuaj           Phd
# 4  Gaurav   33    Jaunpur        B.Tech
# 5    Anuj   36     Kanpur         B.com
# 6  Princi   27  Allahabad           Msc
# 7    Abhi   32    Aligarh            MA

# %%
g=df.groupby("Address")

# %%
for Address,Address_df in g:
    print(Address)
    print(Address_df)
# Out:
# Aligarh
#    Name  Age  Address Qualification
# 7  Abhi   32  Aligarh            MA
# Allahabad
#      Name  Age    Address Qualification
# 2     Jai   22  Allahabad           MCA
# 6  Princi   27  Allahabad           Msc
# Jaunpur
#      Name  Age  Address Qualification
# 4  Gaurav   33  Jaunpur        B.Tech
# Kannuaj
#      Name  Age  Address Qualification
# 3  Princi   32  Kannuaj           Phd
# Kanpur
#    Name  Age Address Qualification
# 1  Anuj   24  Kanpur            MA
# 5  Anuj   36  Kanpur         B.com
# Nagpur
#   Name  Age Address Qualification
# 0  Jai   27  Nagpur           Msc

# %%
df
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1    Anuj   24     Kanpur            MA
# 2     Jai   22  Allahabad           MCA
# 3  Princi   32    Kannuaj           Phd
# 4  Gaurav   33    Jaunpur        B.Tech
# 5    Anuj   36     Kanpur         B.com
# 6  Princi   27  Allahabad           Msc
# 7    Abhi   32    Aligarh            MA

# %%
df.groupby("Address")["Name"].count()
# Out:
# Address
# Aligarh      1
# Allahabad    2
# Jaunpur      1
# Kannuaj      1
# Kanpur       2
# Nagpur       1
# Name: Name, dtype: int64

# %%
#  print the first entries 
# in all the groups formed.
g.first()
# Out:
#              Name  Age Qualification
# Address
# Aligarh      Abhi   32            MA
# Allahabad     Jai   22           MCA
# Jaunpur    Gaurav   33        B.Tech
# Kannuaj    Princi   32           Phd
# Kanpur       Anuj   24            MA
# Nagpur        Jai   27           Msc

# %%
g.groups
# Out:
# {'Aligarh': [7], 'Allahabad': [2, 6], 'Jaunpur': [4], 'Kannuaj': [3], 'Kanpur': [1, 5], 'Nagpur': [0]}

# %%
g=df.groupby(["Address","Qualification"])

# %%
g.describe()
# Out:
#                           Age
#                         count  mean std   min   25%   50%   75%   max
# Address   Qualification
# Aligarh   MA              1.0  32.0 NaN  32.0  32.0  32.0  32.0  32.0
# Allahabad MCA             1.0  22.0 NaN  22.0  22.0  22.0  22.0  22.0
#           Msc             1.0  27.0 NaN  27.0  27.0  27.0  27.0  27.0
# Jaunpur   B.Tech          1.0  33.0 NaN  33.0  33.0  33.0  33.0  33.0
# Kannuaj   Phd             1.0  32.0 NaN  32.0  32.0  32.0  32.0  32.0
# Kanpur    B.com           1.0  36.0 NaN  36.0  36.0  36.0  36.0  36.0
#           MA              1.0  24.0 NaN  24.0  24.0  24.0  24.0  24.0
# Nagpur    Msc             1.0  27.0 NaN  27.0  27.0  27.0  27.0  27.0

# %%
g=df.groupby("Address")

# %%
g.get_group("Allahabad")
# Out:
#      Name  Age    Address Qualification
# 2     Jai   22  Allahabad           MCA
# 6  Princi   27  Allahabad           Msc

# %%
g.max()
# Out:
#              Name  Age Qualification
# Address
# Aligarh      Abhi   32            MA
# Allahabad  Princi   27           Msc
# Jaunpur    Gaurav   33        B.Tech
# Kannuaj    Princi   32           Phd
# Kanpur       Anuj   36            MA
# Nagpur        Jai   27           Msc

# %%
g.min()
# Out:
#              Name  Age Qualification
# Address
# Aligarh      Abhi   32            MA
# Allahabad     Jai   22           MCA
# Jaunpur    Gaurav   33        B.Tech
# Kannuaj    Princi   32           Phd
# Kanpur       Anuj   24         B.com
# Nagpur        Jai   27           Msc

# %%
# %matplotlib inline
g.plot()
# Out:
# Address
# Aligarh      Axes(0.125,0.11;0.775x0.77)
# Allahabad    Axes(0.125,0.11;0.775x0.77)
# Jaunpur      Axes(0.125,0.11;0.775x0.77)
# Kannuaj      Axes(0.125,0.11;0.775x0.77)
# Kanpur       Axes(0.125,0.11;0.775x0.77)
# Nagpur       Axes(0.125,0.11;0.775x0.77)
# dtype: object
