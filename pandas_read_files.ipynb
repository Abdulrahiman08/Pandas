# %%
import pandas as pd

# %%
df=pd.read_csv("webscraping_output.csv")

# %%
df.drop(["Unnamed: 0","Unnamed: 1","Unnamed: 7"],axis=1,inplace=True)

# %%
df.rename(columns={"% ofworld":"Percentage","Source (official or fromthe United Nations)":"Source"},inplace=True)

# %%
df
# Out:
#                                 Location   Population Percentage         Date  \
# 0                          United States  335,893,238       4.1%   1 Jan 2024
# 1                              Indonesia  279,118,866       3.4%   1 Jul 2023
# 2                               Pakistan  241,499,431       3.0%   1 Mar 2023
# 3                                Nigeria  223,800,000       2.8%   1 Jul 2023
# 4                                 Brazil  203,080,756       2.5%   1 Aug 2022
# ..                                   ...          ...        ...          ...
# 233                                 Niue        1,689         0%  11 Nov 2022
# 234                         Tokelau (NZ)        1,647         0%   1 Jan 2019
# 235                         Vatican City          764         0%  26 Jun 2023
# 236  Cocos (Keeling) Islands (Australia)          593         0%  30 Jun 2020
# 237                Pitcairn Islands (UK)           47         0%   1 Jul 2021
#
# ...

# %%
df.to_csv("Sample_data.csv")

# %%
# read_csv -- used to read csv file 
df=pd.read_csv("Sample_data.csv")

# %%
df
# Out:
#      Unnamed: 0                             Location   Population Percentage  \
# 0             0                        United States  335,893,238       4.1%
# 1             1                            Indonesia  279,118,866       3.4%
# 2             2                             Pakistan  241,499,431       3.0%
# 3             3                              Nigeria  223,800,000       2.8%
# 4             4                               Brazil  203,080,756       2.5%
# ..          ...                                  ...          ...        ...
# 233         233                                 Niue        1,689         0%
# 234         234                         Tokelau (NZ)        1,647         0%
# 235         235                         Vatican City          764         0%
# 236         236  Cocos (Keeling) Islands (Australia)          593         0%
# 237         237                Pitcairn Islands (UK)           47         0%
#
# ...

# %%
#skiprows----used to skip the rows from Top 
df=pd.read_csv("Sample_data.csv",skiprows=0)

# %%
df
# Out:
#      Unnamed: 0                             Location   Population Percentage  \
# 0             0                        United States  335,893,238       4.1%
# 1             1                            Indonesia  279,118,866       3.4%
# 2             2                             Pakistan  241,499,431       3.0%
# 3             3                              Nigeria  223,800,000       2.8%
# 4             4                               Brazil  203,080,756       2.5%
# ..          ...                                  ...          ...        ...
# 233         233                                 Niue        1,689         0%
# 234         234                         Tokelau (NZ)        1,647         0%
# 235         235                         Vatican City          764         0%
# 236         236  Cocos (Keeling) Islands (Australia)          593         0%
# 237         237                Pitcairn Islands (UK)           47         0%
#
# ...

# %%
# header - 1.used to set which ever row we want as header , or 2.if there is No header in csv we set new header 
#1. we have set the 4 th row as header , data starts from 5th row
df=pd.read_csv("Sample_data.csv",header=4)

# %%
df
# Out:
#        3                              Nigeria  223,800,000  2.8%   1 Jul 2023  \
# 0      4                               Brazil  203,080,756  2.5%   1 Aug 2022
# 1      5                           Bangladesh  169,828,911  2.1%  14 Jun 2022
# 2      6                               Russia  146,150,789  1.8%   1 Jan 2024
# 3      7                               Mexico  129,625,968  1.6%  31 Dec 2023
# 4      8                                Japan  123,990,000  1.5%   1 Feb 2024
# ..   ...                                  ...          ...   ...          ...
# 229  233                                 Niue        1,689    0%  11 Nov 2022
# 230  234                         Tokelau (NZ)        1,647    0%   1 Jan 2019
# 231  235                         Vatican City          764    0%  26 Jun 2023
# 232  236  Cocos (Keeling) Islands (Australia)          593    0%  30 Jun 2020
# 233  237                Pitcairn Islands (UK)           47    0%   1 Jul 2021
#
# ...

# %%
#2.if there is No header  we can add new header 
df=pd.read_csv("Sample_data.csv",skiprows=1,header=None,names=["Rank","Country","Population","%","data source"])

# %%
df
# Out:
#                                     Rank      Country Population            %  \
# 0                          United States  335,893,238       4.1%   1 Jan 2024
# 1                              Indonesia  279,118,866       3.4%   1 Jul 2023
# 2                               Pakistan  241,499,431       3.0%   1 Mar 2023
# 3                                Nigeria  223,800,000       2.8%   1 Jul 2023
# 4                                 Brazil  203,080,756       2.5%   1 Aug 2022
# ..                                   ...          ...        ...          ...
# 233                                 Niue        1,689         0%  11 Nov 2022
# 234                         Tokelau (NZ)        1,647         0%   1 Jan 2019
# 235                         Vatican City          764         0%  26 Jun 2023
# 236  Cocos (Keeling) Islands (Australia)          593         0%  30 Jun 2020
# 237                Pitcairn Islands (UK)           47         0%   1 Jul 2021
#
# ...

# %%
# nrows--- read required number of rows 
df=pd.read_csv("Sample_data.csv",nrows=6)

# %%
df.set_index("Location",inplace=True)

# %%
df
# Out:
#                 Population Percentage         Date  \
# Location
# United States  335,893,238       4.1%   1 Jan 2024
# Indonesia      279,118,866       3.4%   1 Jul 2023
# Pakistan       241,499,431       3.0%   1 Mar 2023
# Nigeria        223,800,000       2.8%   1 Jul 2023
# Brazil         203,080,756       2.5%   1 Aug 2022
# Bangladesh     169,828,911       2.1%  14 Jun 2022
#
#                                       Source
# Location
# United States           Official estimate[7]
# Indonesia      National annual projection[8]
# Pakistan               2023 census result[9]
# Nigeria              Official projection[10]
# Brazil                2022 census result[11]
# Bangladesh            2022 census result[12]

# %%
#na_values --convert the data into NaN
df=pd.read_csv("Sample_data.csv",na_values=["0%","0.1%"])
# it converts given values into NaN in the Columns

# %%
df
# Out:
#      Unnamed: 0                             Location   Population Percentage  \
# 0             0                        United States  335,893,238       4.1%
# 1             1                            Indonesia  279,118,866       3.4%
# 2             2                             Pakistan  241,499,431       3.0%
# 3             3                              Nigeria  223,800,000       2.8%
# 4             4                               Brazil  203,080,756       2.5%
# ..          ...                                  ...          ...        ...
# 233         233                                 Niue        1,689        NaN
# 234         234                         Tokelau (NZ)        1,647        NaN
# 235         235                         Vatican City          764        NaN
# 236         236  Cocos (Keeling) Islands (Australia)          593        NaN
# 237         237                Pitcairn Islands (UK)           47        NaN
#
# ...

# %%
# if we want to converrt the given values to NaN for a perticular Row instaed of list we can give dic
df=pd.read_csv("Sample_data.csv",na_values={"Percentage":["0%","0.1%"],"Source":["Official estimate[7]"]},nrows=6)

# %%
df
# Out:
#    Unnamed: 0       Location   Population Percentage         Date  \
# 0           0  United States  335,893,238       4.1%   1 Jan 2024
# 1           1      Indonesia  279,118,866       3.4%   1 Jul 2023
# 2           2       Pakistan  241,499,431       3.0%   1 Mar 2023
# 3           3        Nigeria  223,800,000       2.8%   1 Jul 2023
# 4           4         Brazil  203,080,756       2.5%   1 Aug 2022
# 5           5     Bangladesh  169,828,911       2.1%  14 Jun 2022
#
#                           Source
# 0                            NaN
# 1  National annual projection[8]
# 2          2023 census result[9]
# 3        Official projection[10]
# 4         2022 census result[11]
# 5         2022 census result[12]

# %%
df
# Out:
#    Unnamed: 0       Location   Population Percentage         Date  \
# 0           0  United States  335,893,238       4.1%   1 Jan 2024
# 1           1      Indonesia  279,118,866       3.4%   1 Jul 2023
# 2           2       Pakistan  241,499,431       3.0%   1 Mar 2023
# 3           3        Nigeria  223,800,000       2.8%   1 Jul 2023
# 4           4         Brazil  203,080,756       2.5%   1 Aug 2022
# 5           5     Bangladesh  169,828,911       2.1%  14 Jun 2022
#
#                           Source
# 0                            NaN
# 1  National annual projection[8]
# 2          2023 census result[9]
# 3        Official projection[10]
# 4         2022 census result[11]
# 5         2022 census result[12]

# %%
#to_csv -- convert dataframe into Csv file 
df.to_csv("Sample2.csv",index=False)

# %%
#if we want only pericular columns to export Not all the columns 
df.to_csv("Sample1.csv",columns=["Location","Percentage"])

# %%
df
# Out:
#    Unnamed: 0       Location   Population Percentage         Date  \
# 0           0  United States  335,893,238       4.1%   1 Jan 2024
# 1           1      Indonesia  279,118,866       3.4%   1 Jul 2023
# 2           2       Pakistan  241,499,431       3.0%   1 Mar 2023
# 3           3        Nigeria  223,800,000       2.8%   1 Jul 2023
# 4           4         Brazil  203,080,756       2.5%   1 Aug 2022
# 5           5     Bangladesh  169,828,911       2.1%  14 Jun 2022
#
#                           Source
# 0                            NaN
# 1  National annual projection[8]
# 2          2023 census result[9]
# 3        Official projection[10]
# 4         2022 census result[11]
# 5         2022 census result[12]

# %%
#if we dont want header to export
df.to_csv("Sample2.csv",header=False)

# %%
df
# Out:
#    Unnamed: 0       Location   Population Percentage         Date  \
# 0           0  United States  335,893,238       4.1%   1 Jan 2024
# 1           1      Indonesia  279,118,866       3.4%   1 Jul 2023
# 2           2       Pakistan  241,499,431       3.0%   1 Mar 2023
# 3           3        Nigeria  223,800,000       2.8%   1 Jul 2023
# 4           4         Brazil  203,080,756       2.5%   1 Aug 2022
# 5           5     Bangladesh  169,828,911       2.1%  14 Jun 2022
#
#                           Source
# 0                            NaN
# 1  National annual projection[8]
# 2          2023 census result[9]
# 3        Official projection[10]
# 4         2022 census result[11]
# 5         2022 census result[12]

# %%
df.to_excel("sample_data.xlsx",columns=["Location","Population","Percentage","Date","Source"],index=False)

# %%
df=pd.read_excel("sample_data.xlsx")

# %%
df
# Out:
#         Location   Population Percentage         Date  \
# 0  United States  335,893,238       4.1%   1 Jan 2024
# 1      Indonesia  279,118,866       3.4%   1 Jul 2023
# 2       Pakistan  241,499,431       3.0%   1 Mar 2023
# 3        Nigeria  223,800,000       2.8%   1 Jul 2023
# 4         Brazil  203,080,756       2.5%   1 Aug 2022
# 5     Bangladesh  169,828,911       2.1%  14 Jun 2022
#
#                           Source
# 0                            NaN
# 1  National annual projection[8]
# 2          2023 census result[9]
# 3        Official projection[10]
# 4         2022 census result[11]
# 5         2022 census result[12]

# %%
#converters
def convert_Sournce_Cell(Cell):
    if Cell=="National annual projection[8]":
        return "2022 census result"
    return Cell
df=pd.read_excel("sample_data.xlsx",converters={"Source":convert_Sournce_Cell})

# %%
df
# Out:
#         Location   Population Percentage         Date                   Source
# 0  United States  335,893,238       4.1%   1 Jan 2024                      NaN
# 1      Indonesia  279,118,866       3.4%   1 Jul 2023       2022 census result
# 2       Pakistan  241,499,431       3.0%   1 Mar 2023    2023 census result[9]
# 3        Nigeria  223,800,000       2.8%   1 Jul 2023  Official projection[10]
# 4         Brazil  203,080,756       2.5%   1 Aug 2022   2022 census result[11]
# 5     Bangladesh  169,828,911       2.1%  14 Jun 2022   2022 census result[12]

# %%
df
# Out:
#         Location   Population Percentage         Date                   Source
# 0  United States  335,893,238       4.1%   1 Jan 2024                      NaN
# 1      Indonesia  279,118,866       3.4%   1 Jul 2023       2022 census result
# 2       Pakistan  241,499,431       3.0%   1 Mar 2023    2023 census result[9]
# 3        Nigeria  223,800,000       2.8%   1 Jul 2023  Official projection[10]
# 4         Brazil  203,080,756       2.5%   1 Aug 2022   2022 census result[11]
# 5     Bangladesh  169,828,911       2.1%  14 Jun 2022   2022 census result[12]

# %%
#startrow ,#startcol --- it writes from that particular row and col

df.to_excel("sample_data.xlsx",index=False,startrow=2,startcol=4)

# %%
df.to_excel("sample_data.xlsx",index=False)

# %%
df=pd.read_excel("sample_data.xlsx")

# %%
df
# Out:
#         Location   Population Percentage         Date                   Source
# 0  United States  335,893,238       4.1%   1 Jan 2024                      NaN
# 1      Indonesia  279,118,866       3.4%   1 Jul 2023       2022 census result
# 2       Pakistan  241,499,431       3.0%   1 Mar 2023    2023 census result[9]
# 3        Nigeria  223,800,000       2.8%   1 Jul 2023  Official projection[10]
# 4         Brazil  203,080,756       2.5%   1 Aug 2022   2022 census result[11]
# 5     Bangladesh  169,828,911       2.1%  14 Jun 2022   2022 census result[12]

# %%
#ExcelWriter
with pd.ExcelWriter("sample_data.xlsx") as Writer:
    df.to_excel(Writer,sheet_name="new")
    df.to_excel(Writer,sheet_name="new1")
